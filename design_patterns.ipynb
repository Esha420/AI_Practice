# %%
# !pip install google-generativeai

import google.generativeai as genai
from google.colab import userdata

# Load Gemini API key from Colab secrets
GEMINI_API_KEY = userdata.get("GEMINI_API_KEY")

if not GEMINI_API_KEY:
    raise ValueError("❌ GEMINI_API_KEY not found in Colab secrets. Add it in the sidebar under 'Secrets'.")

# Configure Gemini
genai.configure(api_key=GEMINI_API_KEY)

# Initialize model
model = genai.GenerativeModel("gemini-2.0-flash")

print("✅ Gemini ready!")
# Out:
# Requirement already satisfied: google-generativeai in /usr/local/lib/python3.12/dist-packages (0.8.5)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (2.28.1)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (2.187.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (2.38.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (5.29.5)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (2.11.10)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (4.67.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (4.15.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core->google-generativeai) (1.72.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /usr/local/lib/python3.12/dist-packages (from google-api-core->google-generativeai) (2.32.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai) (4.9.1)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai) (0.31.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai) (0.2.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai) (4.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic->google-generativeai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->google-generativeai) (0.4.2)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.2)
# Requirement already satisfied: pyparsing<4,>=3.0.4 in /usr/local/lib/python3.12/dist-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.2.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2025.10.5)
# ✅ Gemini ready!

# %%
#controlled flow pattern
def controlled_flow_agent(task):
    if "summary" in task:
        prompt = f"Summarize this: {task}"
    elif "translate" in task:
        prompt = f"Translate this into English: {task}"
    else:
        prompt = f"Answer this: {task}"

    response = model.generate_content(prompt)
    return response.text

print(controlled_flow_agent("summary cats are fluffy animals"))
# Out:
# Okay, here's a one-sentence summary of "summary cats are fluffy animals":
#
# **Cats, in summary, are fluffy animals.**

# %%
#LLM Router Pattern
def router_agent(query):
    route = model.generate_content(
        "Classify task as summary, sentiment, or math: " + query
    ).text.lower()

    if "summary" in route:
        return "→ Routed to summary module"
    elif "sentiment" in route:
        return "→ Routed to sentiment module"
    else:
        return "→ Routed to math module"

print(router_agent("Summarize this text about AI."))
# Out:
# → Routed to summary module

# %%
import asyncio
import google.generativeai as genai

async def ask(prompt):
    # Run blocking Gemini call in a background thread
    response = await asyncio.to_thread(model.generate_content, prompt)
    return response.text

async def run_parallel():
    tasks = [
        ask("Tell me a joke"),
        ask("Explain gravity"),
        ask("How to cook rice?")
    ]
    results = await asyncio.gather(*tasks)
    print(results)

await run_parallel()
# Out:
# ["Why don't scientists trust atoms?\n\nBecause they make up everything!\n", 'Okay, let\'s break down gravity. It\'s a fundamental force that governs the universe, and while we experience it every day, it\'s a fascinating and complex phenomenon. Here\'s a simplified explanation:\n\n**In Essence:**\n\nGravity is the force of attraction between any two objects that have mass.  The more mass an object has, the stronger its gravitational pull. The closer two objects are, the stronger the gravitational force between them.\n\n**The Basic Principles:**\n\n*   **Everything with mass attracts everything else with mass:** You, the Earth, the Sun, even a tiny speck of dust—everything pulls on everything else.\n*   **Mass Matters:** The more mass an object has, the stronger its gravitational pull. That\'s why the Earth\'s gravity is so much stronger than your own; it has a vastly greater mass.\n*   **Distance Matters:** The strength of gravity decreases rapidly with distance. Specifically, it decreases with the square of the distance. This is known as the inverse square law.  If you double the distance between two objects, the gravitational force between them becomes four times weaker (1/2 squared = 1/4).\n\n**Newton\'s Law of Universal Gravitation:**\n\nIsaac Newton was the first to formulate a mathematical law to describe gravity. His law states:\n\n*   The gravitational force (F) between two objects is directly proportional to the product of their masses (m1 and m2) and inversely proportional to the square of the distance (r) between their centers.\n\nThe formula is:\n\nF = G * (m1 * m2) / r²\n\nWhere:\n\n*   F is the gravitational force\n*   G is the gravitational constant (a very small number)\n*   m1 and m2 are the masses of the two objects\n*   r is the distance between the centers of the two objects\n\n**What Gravity Does:**\n\n*   **Keeps us on the ground:** Earth\'s gravity pulls us towards its center, preventing us from floating off into space.\n*   **Orbits:** Gravity keeps the planets in orbit around the Sun, and the Moon in orbit around the Earth.\n*   **Tides:** The Moon\'s gravity (and to a lesser extent, the Sun\'s gravity) causes the tides in our oceans.\n*   **Formation of Stars and Galaxies:** Gravity pulls together vast clouds of gas and dust, eventually forming stars and galaxies.\n*   **Shapes of Celestial Objects:**  Gravity is why planets and stars are generally spherical.  It pulls matter towards the center, creating a round shape.\n\n**Einstein\'s Theory of General Relativity (A More Advanced View):**\n\nWhile Newton\'s law is excellent for many everyday calculations, Albert Einstein\'s theory of General Relativity provides a more accurate and deeper understanding of gravity.\n\n*   **Gravity is not a force, but a curvature of spacetime:**  Einstein proposed that massive objects warp the fabric of spacetime (a four-dimensional concept combining the three dimensions of space with time).\n*   **Objects follow the curves in spacetime:**  When an object moves through spacetime near a massive object, it follows the curves created by the massive object\'s gravity.  This is what we perceive as gravity.  Imagine placing a bowling ball on a stretched rubber sheet; it creates a dip. If you roll a marble across the sheet, it will curve towards the bowling ball. This is an analogy for how gravity works according to General Relativity.\n*   **Explains Phenomena Newton\'s Law Cannot:**  General Relativity explains phenomena like the bending of light around massive objects (gravitational lensing) and the existence of black holes, which Newton\'s law couldn\'t adequately account for.\n*   **Gravitational Waves:** General Relativity predicts the existence of gravitational waves, ripples in spacetime caused by accelerating massive objects.  These waves have been detected, confirming Einstein\'s theory.\n\n**Key Takeaways:**\n\n*   Gravity is a fundamental force of attraction between objects with mass.\n*   The more massive an obje ...

# %%
#Human in loop pattern
def human_in_loop_example():
    plan = model.generate_content("Create a 3-step plan to learn Python.").text
    print("AI PLAN:")
    print(plan)
    choice = input("\nApprove this plan? (yes/no): ")
    print("You said:", choice)

human_in_loop_example()
# Out:
# AI PLAN:
# Okay, here's a 3-step plan to get you learning Python, focusing on building a solid foundation and practical skills:
#
# **Step 1: The Fundamentals - Getting Grounded (2-4 weeks)**
#
# *   **Goal:** Learn the core syntax, data types, and control flow of Python. You should be able to understand and write simple Python programs that solve basic problems.
# *   **Resources:**
#     *   **Choose a Good Introductory Course:**  Pick one (don't try to do too many at once). Good options include:
#         *   **Codecademy's "Learn Python 3"** (Interactive, good for beginners)
#         *   **FreeCodeCamp's "Scientific Computing with Python" Certification (First five modules are Python Basics)** (Video-based, hands-on projects)
#         *   **Google's Python Class** (Lecture videos and written materials)
#         *   **Automate the Boring Stuff with Python** (Focuses on practical automation tasks)
#     *   **Python.org's Official Tutorial:** A solid, concise introduction.  Good to refer to after some initial learning.
#     *   **Books (Optional):** "Python Crash Course" is a highly recommended beginner-friendly book.
# *   **Topics to Cover:**
#     *   **Basic Syntax:**  Variables, operators, comments.
#     *   **Data Types:**  Integers, floats, strings, booleans, lists, tuples, dictionaries, sets.
#     *   **Control Flow:**  `if`, `elif`, `else` statements, `for` loops, `while` loops.
#     *   **Functions:** Defining functions, passing arguments, returning values.
#     *   **Input/Output:**  Reading from the console, writing to the console.
#     *   **Basic String Manipulation:** Formatting strings, slicing strings.
#     *   **Error Handling (Basic):** `try...except` blocks to catch and handle errors.
# *   **Practice:**
#     *   **Code Along with the Course:**  Don't just watch videos or read; type the code and experiment.
#     *   **Small Coding Exercises:**
#         *   Write a program to calculate the area of a triangle.
#         *   Write a function to check if a number is prime.
#         *   Write a program to reverse a string.
#         *   Create a simple calculator program.
#         *   Write a program to read data from a file and print it.
#     *   **Use Online Coding Platforms:**  LeetCode, HackerRank, CodingBat have beginner-friendly Python problems. Start with the easy ones.
#
# **Step 2: Diving Deeper - Expanding Your Toolkit (4-6 weeks)**
#
# *   **Goal:**  Learn object-oriented programming (OOP), work with modules and libraries, and build more complex programs.
# *   **Resources:**
#     *   **OOP Course/Tutorial:**
#         *   Continue with your chosen intro course if it covers OOP well.
#         *   Otherwise, search for a dedicated Python OOP tutorial (e.g., on YouTube or a separate Codecademy course).
#     *   **Documentation:**  Learn to read the official Python documentation (docs.python.org). This is essential for using libraries effectively.
# *   **Topics to Cover:**
#     *   **Object-Oriented Programming (OOP):**
#         *   Classes, objects, inheritance, polymorphism, encapsulation.
#         *   Understanding `self`, constructors (`__init__`), methods.
#     *   **Modules and Libraries:**
#         *   Importing modules (`import`).
#         *   Using standard libraries: `math`, `datetime`, `os`, `random`, `collections`.
#         *   Installing external libraries using `pip`.
#     *   **File Handling (Advanced):**  Reading and writing different file formats (CSV, JSON).
#     *   **Regular Expressions (Regex - Basic):** Pattern matching in strings using the `re` module.
#     *   **Data Structures (Advanced):**  Queues, stacks, linked lists (implementation and usage).
# *   **Practice:**
#     *   **OOP Projects:**
#         *   Create a class for a `BankAccount`.
#         *   Create a class for a `Shape` with subclasses for `Circle`, `Rectangle`, etc.
#         *   Build a simple inventory management system.
#     *   **Library-Based Projects:**
#         *   Write a script to get the current date and time.
#         *   Write a program to generate random passwords.
#         *   Create a program that reads data from a CSV file and performs some calculations.
#     *   **Small Utilities:** Automate repetitive tasks using Python scripts.
#
# **Step 3:  Applying Your Skills - Building Projects (Ongoing)**
#
# *   **Goal:**  Build larger, more complex projects that demonstrate your skills and solve real-world problems.  Focus on areas that interest you.
# *   **Resources:**
#     *   **Project Ideas:**  Look for inspiration on GitHub, blogs, or by identifying problems you want to solve.
#     *   **Documentation:**  Become proficient at reading documentation for libraries and frameworks.
#     *   **Online Communities:**  Stack Overflow, Reddit's r/learnpython, Python Discord servers are great for asking questions and getting help.
# *   **Project Ideas (Choose one or more based on your interests):**
#     *   **Web Development:**
#         *   Build a simple website using Flask or Django.
#         *   Create a REST API.
#     *   **Data Science/Machine Learning:**
#         *   Analyze a dataset using Pandas and NumPy.
#         *   Build a machine learning model using Scikit-learn.
#     *   **Game Development:**
#         *   Create a simple game using Pygame.
#     *   **Automation:**
#         *   Automate tasks like downloading files, sending emails, or managing social media.
#     *   **Desktop Applications:**
#         *   Build a GUI application using Tkinter or PyQt.
# *   **Focus on Best Practices:**
#     *   **Code Style:**  Follow PEP 8 (Python Enhancement Proposal 8) guidelines for code formatting.
#     *   **Version Control:**  Use Git and GitHub for managing your code.
#     *   **Testing:**  Write unit tests to ensure your code works correctly.
#     *   **Documentation:**  Write clear and concise documentation for your projects.
# *   **Key Actions:**
#     *   **Contribute to Open Source:**  Find a Python project on GitHub that you're interested in and contribute to it.
#     *   **Build a Portfolio:**  Showcase your projects on GitHub or a personal website.
#     *   **Network with Other Developers:**  Attend meetups, conferences, or online forums to connect with other Python developers.
#
# **Important Considerations:**
#
# *   **Consistency is Key:**  Set aside dedicated time each day or week to learn and practice. Even 30 minutes a day is better than sporadic long sessions.
# *   **Don't Be Afraid to Ask for Help:**  The Python community is very welcoming. Don't hesitate to ask questions on forums or online communities.
# *   **Embrace Errors:**  Errors are a normal part of the learning process. Learn to read error messages and debug your code.  Use Google and Stack Overflow to find solutions.
# *   **Stay Curious:**  Python is a vast language with many different applications.  Explore different areas and find what interests you.
# *   **Document Everything:** Taking notes on what you've learned can be really helpful for recalling things later on.
#
# Good luck on your Python journey!  Have fun and keep learning!
#
#
# Approve this plan? (yes/no): yes
# You said: yes

# %%
#reflection Pattern
def reflective_agent(prompt):
    draft = model.generate_content(f"Draft an answer: {prompt}").text

    critique = model.generate_content(
        f"Critique this answer and suggest improvements:\n{draft}"
    ).text

    improved = model.generate_content(
        f"Rewrite the answer using this critique:\n{critique}\nDraft: {draft}"
    ).text

    return improved

print(reflective_agent("Explain quantum computing like I'm 10."))
# Out:
# Okay, here's the rewritten explanation, incorporating all the feedback and aiming for both accessibility and accuracy:
#
# Okay, imagine a regular light switch. It can be either ON or OFF, right? That's like a regular computer bit, representing a 1 (ON) or a 0 (OFF).
#
# Now, imagine a special light switch. This switch isn't just ON or OFF; it can be in a *combination* of being ON and OFF simultaneously. It's more like it has a *probability* of being ON and a *probability* of being OFF. This might sound strange, and it's kind of what a quantum bit, called a "qubit," is like.
#
# Think of it like a spinning coin. Before it lands, it's not definitively heads or tails. It exists in a *superposition* – a mixture of both possibilities. A qubit can be a 0, a 1, or a superposition of both states. This superposition is described by probabilities - perhaps a 70% chance of being a 0 and a 30% chance of being a 1. Importantly, the "spinning" isn't a physical spinning inside the computer, but represents these probabilities.
#
# Why is this special? Well, imagine you're trying to find the best route on a map. A regular computer might try each route one at a time until it finds the shortest.
#
# A quantum computer, because its qubits can be in multiple states at once, can explore *many* routes simultaneously. It explores the possibilities much more efficiently than a regular computer.
#
# Another key idea is *entanglement*. Imagine two of our special light switches, linked together in a strange way. Even if they're far apart, when you measure one and find it's ON, you instantly know the other is OFF (or vice-versa, depending on how they're linked). This connection, called entanglement, allows qubits to work together in powerful ways.
#
# This lets quantum computers tackle some really hard problems much, MUCH faster than regular computers. Things like designing new medicines (by simulating how molecules interact), creating new materials (with specific properties), or even breaking some types of encryption.
#
# For example, think about searching a very large phone book for a specific name. A classical computer would have to look at each name individually. A quantum computer, using superposition and entanglement, could be programmed to effectively search many names *simultaneously* and quickly find the right one, if it exists.
#
# But here's the tricky part. When you measure the 'spinning coin' to see if it's heads or tails (or *measure* a qubit), it *collapses* into one definite state – either heads or tails (either a 0 or a 1). It's *not* like the coin stopping spinning, but rather the measurement forces it to *become* either heads or tails. The superposition is gone. So, we have to be very clever about how we design algorithms to use this superpower before the qubits collapse.
#
# So, quantum computers are potentially super powerful because they can exist in multiple states at once and leverage entanglement, but they are also super delicate and tricky to use. They're still a relatively new technology, and scientists are working hard to make them even better and more useful. They are like the super-powered, but still developing, problem-solvers of the future!

# %%
#Tool used pattern (Mock tool)
def calculator(a, b):
    return a + b

def tool_use_agent(query):
    decide = model.generate_content(
        "Does the user want math or explanation? Respond only 'math' or 'explain'.\n" + query
    ).text.lower()

    if "math" in decide:
        return calculator(5, 7)
    else:
        return model.generate_content(query).text

print(tool_use_agent("Add 5 and 7"))
# Out:
# 12

# %%
#ReAct Pattern (Reasoning + Action)
def react_agent(question):
    reasoning = model.generate_content(
        f"Think step-by-step and propose an action for: {question}"
    ).text

    action_result = "Action executed (simulated)"

    final = model.generate_content(
        f"Combine reasoning:\n{reasoning}\nAction result: {action_result}\nGive final answer:"
    ).text

    return final

print(react_agent("How can I improve my sleep?"))
# Out:
# This is a comprehensive and well-reasoned guide to improving sleep. It covers all the key aspects of sleep hygiene and provides actionable steps for individuals to implement. The inclusion of reasoning behind each action is particularly helpful, as it encourages understanding and adherence. The emphasis on patience, individual needs, and seeking professional help when necessary are also important and realistic. The step-by-step approach makes it easy to follow and implement. Excellent advice!

# %%
#Planning Pattern
def planning_agent(goal):
    plan = model.generate_content(f"Break this goal into steps: {goal}").text
    return plan

print(planning_agent("Learn full-stack development"))
# Out:
# Okay, let's break down the ambitious goal of "Learn Full-Stack Development" into manageable steps. I'll categorize them by technology area and provide some recommendations for each.
#
# **I. Foundational Knowledge (Essential for all paths)**
#
# *   **Step 1: Fundamentals of Computer Science (1-3 months):**
#     *   **Goal:** Grasp core programming concepts.
#     *   **Sub-steps:**
#         *   **Choose a Language:** Start with Python or JavaScript. Both are beginner-friendly and widely used. Python is easier to learn initially, while JavaScript is essential for front-end development.
#         *   **Basic Syntax:** Learn variables, data types, operators, control flow (if/else, loops), functions.
#         *   **Data Structures:** Understand arrays (lists), dictionaries (objects), sets, tuples.
#         *   **Algorithms:** Learn basic searching (linear, binary) and sorting (bubble, insertion, selection).
#         *   **Object-Oriented Programming (OOP) (Optional initially, but crucial later):**  Understand classes, objects, inheritance, polymorphism, encapsulation.
#     *   **Resources:**
#         *   **Online Courses:** Codecademy, freeCodeCamp, Khan Academy, Udemy, Coursera (Python or JavaScript tracks).
#         *   **Books:** "Automate the Boring Stuff with Python" (Python), "Eloquent JavaScript" (JavaScript).
#         *   **Practice Platforms:** HackerRank, LeetCode (focus on easy problems).
#     *   **Key:** Practice consistently.  Solve coding challenges regularly.
#
# *   **Step 2: Version Control with Git (1-2 weeks):**
#     *   **Goal:** Learn to track changes to your code and collaborate effectively.
#     *   **Sub-steps:**
#         *   **Install Git:** Download and install Git on your computer.
#         *   **Basic Commands:** Learn `git init`, `git clone`, `git add`, `git commit`, `git push`, `git pull`, `git branch`, `git merge`.
#         *   **GitHub/GitLab/Bitbucket:** Create an account on one of these platforms and learn how to use it to store your code and collaborate.
#     *   **Resources:**
#         *   **Online Courses:** Codecademy, freeCodeCamp, GitHub's official documentation.
#         *   **Interactive Tutorials:**  Learn Git Branching.
#         *   **Practice:** Create your own repositories, commit changes, and practice branching and merging.
#
# *   **Step 3: Command Line Basics (1 week):**
#     *   **Goal:** Become comfortable navigating and manipulating files using the command line.
#     *   **Sub-steps:**
#         *   **Basic Commands:** Learn `cd`, `ls`, `mkdir`, `rm`, `cp`, `mv`, `pwd`, `echo`, `cat`.
#         *   **Learn how to use flags:** Learn how to modify the above commands using flags.
#     *   **Resources:**
#         *   **Online Courses:**  freeCodeCamp's "Command Line Crash Course", The Command Line Crash Course from Zed Shaw.
#         *   **Practice:** Use the command line for everyday tasks like creating folders, moving files, and running programs.
#
# **II. Front-End Development (Focus on User Interface)**
#
# *   **Step 4: HTML (1-2 weeks):**
#     *   **Goal:** Learn the structure and semantics of web pages.
#     *   **Sub-steps:**
#         *   **Basic Tags:** Understand elements like `<h1>` to `<h6>`, `<p>`, `<a>`, `<img>`, `<div>`, `<span>`, `<ul>`, `<ol>`, `<li>`, `<form>`, `<input>`, `<button>`.
#         *   **Semantic HTML:** Use semantic tags like `<article>`, `<nav>`, `<aside>`, `<header>`, `<footer>` to structure your content meaningfully.
#         *   **Forms:** Learn how to create forms to collect user input.
#     *   **Resources:**
#         *   **Online Courses:** Codecademy, freeCodeCamp, MDN Web Docs (Mozilla Developer Network).
#         *   **Practice:** Build simple web pages with different layouts and content.
#
# *   **Step 5: CSS (2-4 weeks):**
#     *   **Goal:** Learn how to style web pages and make them visually appealing.
#     *   **Sub-steps:**
#         *   **Basic Selectors:** Learn how to target HTML elements using selectors (e.g., element selectors, class selectors, ID selectors).
#         *   **Box Model:** Understand the CSS box model (content, padding, border, margin).
#         *   **Layout:** Learn different layout techniques like flexbox and grid.
#         *   **Typography:** Learn how to style text using different fonts, sizes, and colors.
#         *   **Responsive Design:**  Learn how to make your website look good on different screen sizes using media queries.
#     *   **Resources:**
#         *   **Online Courses:** Codecademy, freeCodeCamp, MDN Web Docs, CSS-Tricks.
#         *   **Practice:** Style the web pages you created in the HTML step.  Experiment with different layouts and designs.
#
# *   **Step 6: JavaScript Fundamentals (4-8 weeks):**
#     *   **Goal:** Learn how to add interactivity and dynamic behavior to web pages.
#     *   **Sub-steps:**
#         *   **DOM Manipulation:** Learn how to access and modify HTML elements using JavaScript.
#         *   **Events:** Learn how to respond to user events (e.g., clicks, mouseovers, form submissions).
#         *   **Asynchronous JavaScript:** Understand asynchronous programming concepts like callbacks, promises, and async/await.
#         *   **Fetch API:** Learn how to make HTTP requests to fetch data from servers.
#     *   **Resources:**
#         *   **Online Courses:** Codecademy, freeCodeCamp, MDN Web Docs, Udemy (search for JavaScript courses).
#         *   **Books:** "Eloquent JavaScript", "You Don't Know JS" series.
#         *   **Practice:** Build interactive web applications like to-do lists, calculators, and simple games.
#
# *   **Step 7: Front-End Framework (React, Angular, or Vue.js) (4-8 weeks):**
#     *   **Goal:** Learn a popular JavaScript framework to build complex and maintainable user interfaces.  React is generally considered the most popular and has a large community.  Vue.js is easier to learn initially.
#     *   **Sub-steps:**
#         *   **Component-Based Architecture:** Understand how to break down a UI into reusable components.
#         *   **State Management:** Learn how to manage the state of your application.
#         *   **Routing:** Learn how to navigate between different pages or views.
#         *   **Framework-Specific Concepts:** Learn the specific concepts and APIs of the chosen framework (e.g., JSX in React, Templates in Angular, Single File Components in Vue.js).
#     *   **Resources:**
#         *   **React:** React's official documentation, Create React App, freeCodeCamp's React course, Udemy (search for React courses).
#         *   **Angular:** Angular's official documentation, Angular CLI, Udemy (search for Angular courses).
#         *   **Vue.js:** Vue.js's official documentation, Vue CLI, Udemy (search for Vue.js courses).
#         *   **Practice:** Build several projects using the chosen framework, starting with simple examples and gradually increasing complexity.  Focus on building components and managing state effectively.
#
# **III. Back-End Development (Focus on Server-Side Logic and Databases)**
#
# *   **Step 8: Back-End Language and Framework (Python with Django/Flask, Node.js with Express, Ruby on Rails, Java with Spring) (4-8 weeks):**
#     *   **Goal:** Learn a back-end language and framework to handle server-side logic, API endpoints, and database interactions.
#     *   **Sub-steps:**
#         *   **Choose a Stack:**
#             *   **Python/Django:** Popular for its simplicity, rapid development, and scalability. Great for data science and machine learning as well.
#             *   **Node.js/Express:** Uses JavaScript on the server-side, making it a good choice if you already know JavaScript. Highly scalable and suitable for real-time applications.
#             *   **Ruby on Rails:** Known for its convention-over-configuration approach and rapid development.
#             *   **Java/Spring:** Enterprise-level framework, powerful and scalable, but has a steeper learning curve.
#         *   **Learn the Language:** Brush up on your chosen language (Python, JavaScript, Ruby, or Java).
#         *   **Learn the Framework:** Learn the framework's core concepts, routing, middleware, and ORM (Object-Relational Mapper).
#         *   **Build APIs:** Learn how to create RESTful APIs to expose your server-side functionality.
#     *   **Resources:**
#         *   **Python/Django:** Django's official documentation, Django Girls Tutorial, Udemy (search for Django courses), Flask's official documentation (for Flask).
#         *   **Node.js/Express:** Node.js's official documentation, Express's official documentation, freeCodeCamp's Node.js course, Udemy (search for Node.js and Express courses).
#         *   **Ruby on Rails:** Ruby on Rails's official documentation, Rails Guides, Udemy (search for Ruby on Rails courses).
#         *   **Java/Spring:** Spring's official documentation, Spring Initializr, Udemy (search for Java and Spring courses).
#         *   **Practice:** Build APIs for common tasks, like user authentication, data retrieval, and data manipulation.
#
# *   **Step 9: Databases (SQL and/or NoSQL) (2-4 weeks):**
#     *   **Goal:** Learn how to store and retrieve data using databases.
#     *   **Sub-steps:**
#         *   **Choose a Database:**
#             *   **SQL (Relational Databases):** MySQL, PostgreSQL, SQLite.  Good for structured data and transactions.  PostgreSQL is generally considered a more advanced and robust option.
#             *   **NoSQL (Non-Relational Databases):** MongoDB, Cassandra, Redis. Good for unstructured data and scalability.  MongoDB is a popular choice for its document-oriented approach.
#         *   **Learn SQL or NoSQL Fundamentals:**
#             *   **SQL:** Learn how to create tables, insert data, query data (SELECT, WHERE, JOIN), update data, and delete data.
#             *   **NoSQL:** Learn how to create collections/buckets, insert documents, query documents, update documents, and delete documents.
#         *   **ORM (Object-Relational Mapper) (Optional but Recommended):** Learn how to use an ORM to interact with the database from your back-end code (e.g., Django ORM, Sequelize for Node.js).
#     *   **Resources:**
#         *   **SQL:** SQLZoo, Mode Analytics SQL Tutorial, Udemy (search for SQL courses).
#         *   **NoSQL (MongoDB):** MongoDB's official documentation, MongoDB University, Udemy (search for MongoDB courses).
#         *   **Practice:** Design and implement databases for your back-end applications.
#
# *   **Step 10: APIs (2 weeks):**
#     *   **Goal:** Learn how to design, build, and consume APIs.
#     *   **Sub-steps:**
#         *   **Understand RESTful Principles:** Learn the principles of REST (Representational State Transfer) and how to design RESTful APIs.
#         *   **API Design:** Learn how to design API endpoints, request/response formats, and error handling.
#         *   **API Authentication:** Learn how to secure your APIs using authentication mechanisms like API keys, OAuth, or JWT (JSON Web Tokens).
#         *   **API Documentation:** Learn how to document your APIs using tools like Swagger/OpenAPI.
#     *   **Resources:**
#         *   **REST API Tutorials:** REST API Tutorial, freeCodeCamp's API tutorials.
#         *   **API Documentation Tools:** Swagger, Postman.
#         *   **Practice:** Build and document APIs for your back-end applications.
#
# **IV. Deployment and DevOps (Getting Your Application Live)**
#
# *   **Step 11: Deployment (1-2 weeks):**
#     *   **Goal:** Learn how to deploy your application to a live server.
#     *   **Sub-steps:**
#         *   **Choose a Hosting Platform:**
#             *   **Cloud Platforms:** AWS (Amazon Web Services), Google Cloud Platform (GCP), Microsoft Azure. Offer a wide range of services and scalability.
#             *   **Platform-as-a-Service (PaaS):** Heroku, Netlify, Vercel. Simpler and easier to use for deploying web applications.
#         *   **Learn the Deployment Process:** Learn how to configure your server, deploy your code, and configure your database.
#         *   **Domain Name and DNS:**  Learn how to register a domain name and configure DNS settings to point your domain to your server.
#         *   **HTTPS:** Learn how to secure your website with HTTPS using Let's Encrypt or other SSL certificates.
#     *   **Resources:**
#         *   **Platform-Specific Documentation:** AWS documentation, GCP documentation, Azure documentation, Heroku documentation, Netlify documentation, Vercel documentation.
#         *   **Deployment Tutorials:** Search for tutorials on how to deploy your chosen stack to your chosen platform.
#         *   **Practice:** Deploy your projects to a live server.
#
# *   **Step 12: DevOps Fundamentals (Optional but Highly Recommended) (2-4 weeks):**
#     *   **Goal:** Learn the basics of DevOps to automate and streamline your development and deployment processes.
#     *   **Sub-steps:**
#         *   **Continuous Integration/Continuous Deployment (CI/CD):** Learn how to automate the build, test, and deployment process using tools like Jenkins, Travis CI, CircleCI, or GitHub Actions.
#         *   **Containerization (Docker):** Learn how to package your application and its dependencies into containers for easy deployment and scaling.
#         *   **Infrastructure as Code (IaC):** Learn how to manage your infrastructure using code using tools like Terraform or CloudFormation.
#         *   **Monitoring and Logging:** Learn how to monitor your application's performance and log errors using tools like Prometheus, Grafana, or ELK stack (Elasticsearch, Logstash, Kibana).
#     *   **Resources:**
#         *   **DevOps Tutorials:** freeCodeCamp's DevOps course, Udemy (search for DevOps courses).
#         *   **Docker Documentation:** Docker's official documentation.
#         *   **Terraform Documentation:** Terraform's official documentation.
#         *   **Practice:** Set up a CI/CD pipeline for your projects, containerize your applications with Docker, and monitor your application's performance.
#
# **V. Continuous Learning and Project Building**
#
# *   **Step 13: Build Projects, Build Projects, Build Projects!**
#     *   **Goal:** Solidify your knowledge and build a portfolio to showcase your skills.
#     *   **Sub-steps:**
#         *   **Start Small:** Begin with simple projects to practice the fundamentals.
#         *   **Increase Complexity:** Gradually increase the complexity of your projects to challenge yourself and learn new skills.
#         *   **Contribute to Open Source:** Contribute to open-source projects to learn from experienced developers and gain real-world experience.
#         *   **Build a Portfolio:** Create a portfolio website to showcase your projects and skills to potential employers.
#
# *   **Step 14: Stay Up-to-Date:**
#     *   **Goal:** The world of web development is constantly evolving, so it's important to stay up-to-date with the latest trends and technologies.
#     *   **Sub-steps:**
#         *   **Read Blogs and Articles:** Follow blogs and articles from industry leaders and experts.
#         *   **Attend Conferences and Meetups:** Attend conferences and meetups to learn from other developers and network with potential employers.
#         *   **Take Online Courses:** Continue to take online courses to learn new technologies and improve your skills.
#         *   **Experiment with New Technologies:** Experiment with new technologies to see how they work and how they can be used to solve problems.
#
# **Important Considerations:**
#
# *   **Time Commitment:** Full-stack development is a significant undertaking. Be prepared to invest a considerable amount of time and effort.  Consistency is key.
# *   **Choose a Path:** Don't try to learn everything at once. Pick a specific tech stack (e.g., MERN stack - MongoDB, Express, React, Node.js) and focus on mastering it.
# *   **Problem-Solving Skills:** Develop your problem-solving skills. Debugging is a crucial part of development. Learn to use debugging tools and techniques.
# *   **Community:** Join online communities and forums to ask questions, share your knowledge, and get help from other developers (e.g., Stack Overflow, Reddit's webdev and relevant framework subreddits).
# *   **Don't Be Afraid to Ask for Help:**  Everyone gets stuck. Don't be afraid to ask for help from online communities, mentors, or other developers.
# *   **Portfolio is Key:** Employers want to see what you can *do*. Build a solid portfolio of projects that demonstrate your skills.
#
# **Example Project Ideas (Progression):**
#
# *   **Beginner:**
#     *   To-Do List App (Front-end and back-end)
#     *   Simple Blog (Front-end and back-end)
#     *   Weather App (Front-end consuming an API)
# *   **Intermediate:**
#     *   E-commerce Store (Basic product catalog, shopping cart)
#     *   Social Media Clone (Basic posting, commenting)
#     *   Real-Time Chat Application
# *   **Advanced:**
#     *   Complex Data Visualization Dashboard
#     *   Full-Featured E-commerce Platform
#     *   Custom API with Authentication and Authorization
#
# This is a comprehensive breakdown. Remember to adapt it to your learning style, interests, and career goals. Good luck!

# %%
#Multi-Agent Pattern
def agent(role, msg):
    return model.generate_content(
        f"You are {role}. Respond to:\n{msg}"
    ).text

def multi_agent(topic):
    researcher = agent("Researcher", topic)
    editor = agent("Editor", researcher)
    critic = agent("Critic", editor)
    return critic

print(multi_agent("Explain how transformers work"))
# Out:
# Okay, I've reviewed the suggestions, and while the initial explanation is praised, I agree with the proposed improvements. They add crucial nuance and context, making the explanation significantly stronger. Here's my critique of the suggestions themselves:
#
# **Overall Assessment:**
#
# The suggestions are excellent and well-reasoned. They focus on clarity, context, and practicality, which are exactly what elevates technical explanations from good to great. The suggestions are specific and actionable, making them easy to implement. The example snippets are also very helpful.
#
# **Strengths of the Suggestions:**
#
# *   **Focus on "Why":** The suggestions consistently push for explaining *why* things are done a certain way, rather than just stating *what* is done.  This is particularly strong in the recommendations for Input Embeddings and Multi-Head Self-Attention (scaling). Explaining the rationale behind design choices is crucial for true understanding.
# *   **Practicality and Real-World Relevance:** The suggestions about mentioning specific Transformer models (BERT, GPT, T5), regularization techniques, and memory mitigation techniques directly address practical considerations and show the relevance of the theory. This connects the explanation to the real world.
# *   **Clarity and Precision:** The suggestions for rephrasing and clarifying specific sections (e.g., Attention Weights, Masked Multi-Head Self-Attention) are spot-on. These seemingly small changes can significantly improve comprehension.
# *   **Addressing Potential Misconceptions:** Highlighting that masking in the decoder is *only* during training is a critical clarification.  Without it, readers might misunderstand the process.
# *   **Audience Awareness:** The initial point about considering the target audience is fundamental. Tailoring the explanation to the appropriate level is essential for its effectiveness.
#
# **Minor Areas for Further Consideration (Nitpicking, really):**
#
# *   **Visuals:** While mentioning visuals is good, *how* to create effective visuals for Transformers could be briefly touched upon.  For example, highlighting attention matrices or layer diagrams as particularly useful.
# *   **Input Embeddings:** Suggesting pre-trained embeddings is good, but it might be worthwhile to *briefly* mention that embeddings can also be learned end-to-end as part of the Transformer training process. This offers a more complete picture.
# *   **Challenges (Memory Requirements):**  While mentioning sparse attention and low-rank approximations is a good start, briefly mentioning techniques like gradient checkpointing could be added as well, as it's a common method for reducing memory footprint during training.
#
# **Conclusion:**
#
# The suggested improvements are highly valuable and will significantly enhance the explanation of Transformers. They add crucial context, clarity, and practical relevance, making the explanation more comprehensive and understandable. The points regarding explaining *why* and addressing potential misconceptions are particularly strong. Implementing these suggestions would be a significant upgrade. The nitpicks above are just that - very minor suggestions for further refinement.

# %%
#Tree-of-Thoughts Pattern
def tree_of_thoughts(question):
    thoughts = [
        model.generate_content(f"Generate idea #{i} for: {question}").text
        for i in range(1, 4)
    ]

    scored = [
        (t, model.generate_content(f"Score this idea 1-10:\n{t}").text)
        for t in thoughts
    ]

    best = max(scored, key=lambda x: int("".join(filter(str.isdigit, x[1]))))

    return best[0]

print(tree_of_thoughts("How can we reduce food waste?"))
# Out:
# Okay, here's idea #3 for how we can reduce food waste, focusing on a **Community-Based Solution:**
#
# **Idea #3: Community Composting and Gleaning Networks**
#
# *   **Core Concept:** Establish interconnected systems for composting food scraps and rescuing surplus edible produce from local sources.
# *   **Components:**
#     *   **Expanded Community Composting Programs:**
#         *   **Neighborhood Drop-Off Sites:** More readily accessible locations for residents to deposit food scraps (e.g., parks, community centers, schools).
#         *   **Curbside Composting Programs:** Municipalities offer composting bins alongside recycling and trash.
#         *   **Educational Workshops:** Teach residents how to compost effectively and understand the benefits.
#         *   **Partnering with Local Businesses:** Restaurants, grocery stores, and farms can contribute their food waste.
#         *   **Compost Distribution:** Make the finished compost available to community gardens, public parks, and residents for their own gardens.
#     *   **Gleaning Networks:**
#         *   **Volunteer Coordination:** Organize teams of volunteers to harvest surplus crops from farms and orchards after the commercial harvest.
#         *   **Partnerships with Farms:** Build relationships with local farmers to access their excess produce that might otherwise be discarded.
#         *   **Distribution to Food Banks and Charities:** Ensure the gleaned produce reaches people in need through existing food assistance programs.
#         *   **Cold Storage and Processing:** Consider small-scale cold storage facilities or processing centers to extend the shelf life of gleaned produce (e.g., freezing, canning, making jam).
#         *   **Transportation Logistics:** Efficiently transport the gleaned produce from farms to distribution points.
# *   **Benefits:**
#     *   **Reduced Landfill Waste:** Diverts food scraps from landfills, reducing methane emissions.
#     *   **Nutrient Recycling:** Returns valuable nutrients to the soil through composting.
#     *   **Increased Food Security:** Provides fresh produce to food banks and those in need.
#     *   **Community Engagement:** Fosters a sense of community and shared responsibility.
#     *   **Economic Benefits:** Reduces waste disposal costs for municipalities and businesses.
# *   **Challenges:**
#     *   **Logistics:** Managing the collection, transportation, and processing of food scraps and gleaned produce.
#     *   **Funding:** Securing funding for equipment, staff, and infrastructure.
#     *   **Public Awareness:** Educating the public about the benefits of composting and gleaning.
#     *   **Volunteer Recruitment and Management:** Recruiting and training volunteers to participate in the networks.
#     *   **Food Safety:** Ensuring the safety of gleaned produce through proper handling and storage.
# *   **Examples:**
#     *   City of San Francisco's Mandatory Composting Program
#     *   Society of St. Andrew Gleaning Networks
#     *   Local community garden initiatives
#
# This approach focuses on building a system that actively involves the community in reducing food waste at both the beginning (preventing waste by gleaning) and the end (diverting waste by composting) of the food cycle.
